# %% [markdown]
# <a href="https://colab.research.google.com/github/Aldirhezaldi/PCVK_Genap_2021/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **D. PRAKTIKUM**
#
# 1. Buka https://colab.research.google.com/. Setelah dipastikan bahwa google Colab
# terhubung dengan Github Anda, lanjutkan dengan memilih repository yang telah
# digunakan pada praktikum minggu lalu, rename file menjadi “Week2.ipynb”.
# Kemudian import folder yang ada di Drive Anda dengan cara sebagai berikut.
# Jika berhasil, maka Google Colab sudah dapat mengakses folder gdrive Anda dengan
# keterangan output program “Mounted at /content/drive”.

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Kemudian kode program dapat dilanjutkan dengan membuka file Google Drive yang
# sudah ada. Contohnya pada kode program di bawah file image dengan nama
# kitten01.jpg akan dibuka untuk diproses lebih lanjut.

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/image/maxresdefault.jpg')
plt.imshow(img)             #Perhatikan hasilnya adalah citra dengan channel warna RGB

# %% [markdown]
# 2. OpenCV membaca image dan menyimpan dalam channel warna BGR (Blue Green Red)
# Tampilkan nilai pixel dan image

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)    #konversi channel BGR -> RGB
plt.imshow(img3)

# %% [markdown]
# # **TUGAS**
# Berdasarkan praktikum bagian 1 dan 2 kerjakan tugas berikut :
#
#
#
# 1.   Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga berubah ?

# %%
plt.figure( figsize= (10,10))
plt.imshow(img3)

plt.show()

# %% [markdown]
# Jawab : ukuran pixel tidak berubah, hanya memperbesar image

# %% [markdown]
# 2. 2.   Tampilkan image dalam channel Red-Green dan Green-Blue saja!

# %%
imgt2rg = cv.cvtColor(img, cv.COLOR_BGR2RGB)


imgt2rg[:,:,0] = np.zeros([imgt2rg.shape[0], imgt2rg.shape[1]])
plt.imshow(imgt2rg)

# %%
imgt2gb = cv.cvtColor(img, cv.COLOR_BGR2RGB)


imgt2gb[:,:,2] = np.zeros([imgt2gb.shape[0], imgt2gb.shape[1]])
plt.imshow(imgt2gb)

# %% [markdown]
# 3. Tampilkan image baris ke 10-100, kolom 10-100!

# %%
img3t = img3[10:100, 10:100]
plt.imshow(img3t)

# %% [markdown]
# 4. Tampilkan image baris 5-30, semua kolom, channel Green saja!

# %%
plt.imshow(imgt2gb[5:30])

# %% [markdown]
# 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!

# %%
cv.rectangle(img3,(500,500),(650,650),color=(0,255,0),thickness=10)
cv.rectangle(img3,(400,500),(650,650),color=(255,0,0),thickness=10)
cv.rectangle(img3,(200,500),(650,650),color=(0,255,255),thickness=10)
cv.rectangle(img3,(300,500),(650,650),color=(255,255,0),thickness=10)
cv.rectangle(img3,(100,500),(650,650),color=(0,0,0),thickness=10)
plt.imshow(img3)

# %% [markdown]
# 6. Tampilkan image dengan posisi terbalik!

# %%
img6f = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
plt.imshow(img6f)

# %% [markdown]
# 3. Menampilkan citra Grayscale, melakukan resizing, melakukan Flipping, Menyimpan citra hasil

# %%
img_gray = cv.imread('/content/drive/MyDrive/image/maxresdefault.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘gray’

# %%
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘magma’

# %%
plt.imshow(img_gray, cmap='magma')

# %% [markdown]
# Citra RGB di resize dalam ukuran panjang 512 dan lebar 1024

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %% [markdown]
# Citra RGB ditampilkan dalam ukuran yang lebih besar dengan posisi gambar terbalik

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))   #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# 4. Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image dengan tipe data int16.

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %% [markdown]
# Kemudian menambahkan bentuk persegi panjang sesuai koordinat pt1 dan pt2

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %% [markdown]
# Selanjutnya ditambah menambahkan bentuk persegi sesuai koordinat pt1 dan pt2
# yang tertulis pada kode program.

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %% [markdown]
# Tahap selanjutnya ditambah menambahkan bentuk lingkaran sesuai radius yang
# tertulis pada kode program

# %%
cv.circle(black_img, center=(100,100), radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(400,400), radius=50,color=(255,0,0),thickness=-2)
plt.imshow(black_img)

# %% [markdown]
# Kemudian dilakukan penambahan garis sesuai koordinat pt1 dan pt2 sebagai berikut

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
cv.circle(img,(400,400), 63, (0,0,255), -1)
plt.imshow(black_img)

# %% [markdown]
# Penambahan text dengan font yang telah tertulis dengan ukuran yang sudah
# ditentukan

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# Pembuatan black image kembali dilakukan dengan tipe data int32

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %% [markdown]
# Berikut adalah kode program untuk inisialisasi NumPy array dengan tipe data int32

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
# Array tersebut kemudian di reshape sebagai berikut

# %%
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R,G,B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# Penambahan polyline pada black image kedua yang telah dibuat.

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# 5. Setelah semua kode selesai simpan “Week2.ipynb” pada GiHub Anda dengan memilih
# File kemudian “Save a copy in GitHub”.

# %% [markdown]
# # **TUGAS**
#
# Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :
#
# 1.   Buat rectangle dan circle pada bagian wajah dari image foto anda saat
# beraktifitas (bukan pasfoto).

# %%
imgx = cv.imread('/content/drive/MyDrive/image/drive aing.jpeg')

img2x = imgx
img3x = cv.cvtColor(imgx,cv.COLOR_BGR2RGB)    

cv.rectangle(img3x,(1500,1500),(1650,1650),color=(0,255,0),thickness=10)

cv.circle(img3x, center=(1500,2000), radius=50,color=(255,0,0),thickness=8)

plt.imshow(img3x)

# %% [markdown]
# 2. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB
# dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!

# %%
cv.rectangle(img3x,(1000,3800),(100,3000),color=(0,0,255),thickness=15)
plt.imshow(img3x)

# %% [markdown]
# 3. Tulis nama file pada file citra dari soal no.2. Gunakan font, ukuran font, dan
# warna font yang sesuai keinginan anda

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(img3x, text='male.jpg',org=(10,500),fontFace=font,fontScale=10,color=(0,0,255),thickness=6,lineType=cv.LINE_4)
plt.imshow(img3x)

# %% [markdown]
# # **PERTANYAAN**
#
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
# =  Perbedaanya adalah jika menggunakan matplotlib kita sudah diberi method method dari library matplotlib termasuk gambar kita yang sudah ada ukuran panjang dan lebarnya
#
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
#
# =  Perbedaannya adalah pada pengaruh ukuran file gambar, yang dimana int16 memiliki kapasitas file lebih sedikit daripada int32
#
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut
#
# =  google.collab.patches import cv2_imshow untuk menampilkan gambar pada google collab
#
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
#
# =  untuk mengunduh gambar, read dan write gambar
